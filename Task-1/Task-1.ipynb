# %% [markdown]
# # Akshay Reddy Bokkala

# %% [markdown]
# # Task-1

# %% [markdown]
# # Image to Pencil sketch with Python

# %% [markdown]
# ## Installing Packages

# %% [markdown]
# ### OpenCV is a huge open-source library for computer vision, machine learning, and image processing. OpenCV supports a wide variety of programming languages like Python, C++, Java, etc. It can process images and videos to identify objects, faces, or even the handwriting of a human.

# %% [markdown]
# ## Installing packages

# %%
# !pip install opencv-python

# %% [markdown]
# ## Importing packages

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Loading Image

# %%
image = cv2.imread("pikachu.jfif")
cv2.imshow("Pikachu", image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## Converting the Original Image to GrayScale Image:

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(gray_image,cmap="gray")
plt.title(" Grayscale image:")
# Out:
# Text(0.5, 1.0, ' Grayscale image:')

# %% [markdown]
# ## Invert the Grayscale image

# %%
inverted_image = 255 - gray_image
plt.imshow(inverted_image)
plt.title("Black And White Inverted")
# Out:
# Text(0.5, 1.0, 'Black And White Inverted')

# %% [markdown]
# ## Blur the inverted image

# %%
blur_img=cv2.GaussianBlur(inverted_image, (111,111),0)
plt.imshow(blur_img)
plt.title("blurred inverted grayscale image:")
# Out:
# Text(0.5, 1.0, 'blurred inverted grayscale image:')

# %% [markdown]
# ## Convert to pencil sketch

# %%
pencil_sketch = cv2.divide(gray_image, blur_img, scale=256.0)
plt.imshow(pencil_sketch,cmap="gray")
plt.title("Pencil sketch Image")
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
plt.figure(figsize=(14,8))
plt.subplot(1,2,1)
plt.title('Original image', size=18)
plt.imshow(image)
plt.axis('off')
plt.subplot(1,2,2)
plt.title('Pencil Sketch', size=18)
rgb_sketch=cv2.cvtColor(pencil_sketch, cv2.COLOR_BGR2RGB)
plt.imshow(rgb_sketch)
plt.axis('off')
plt.show()
